# %%
import csv
from pathlib import Path
dir_ = r'G:\software\my_software\projects\cfactor_asce7'
csv_path = Path(dir_) / 'systems.csv'
with open(csv_path, 'r') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(row)
# Out:
# ['A. BEARING WALL SYSTEMS', '', 'Ra', '?0g', 'Cdb', 'B', 'C', 'Dd']
# ['1. Special reinforced concrete shear walls', '14.2', '5', '2.5', '5', 'NL', 'NL', 'NL']
# ['2. Ordinary reinforced concrete shear walls', '14.2', '4', '2.5', '4', 'NL', 'NL', 'NP']
# ['3. Detailed plain concrete shear walls', '14.2', '2', '2.5', '2', 'NL', 'NP', 'NP']
# ['4. Ordinary plain concrete shear walls', '14.2', '1.5', '2.5', '1.5', 'NL', 'NP', 'NP']
# ['5. Intermediate precast shear walls', '14.2', '4', '2.5', '4', 'NL', 'NL', '40']
# ['6. Ordinary precast shear walls', '14.2', '3', '2.5', '3', 'NL', 'NP', 'NP']
# ['7. Special reinforced masonry shear walls', '14.4', '5', '2.5', '3.5', 'NL', 'NL', 'NL']
# ['8. Intermediate reinforced masonry shear walls', '14.4', '3.5', '2.5', '2.25', 'NL', 'NL', 'NP']
# ['9. Ordinary reinforced masonry shear walls', '14.4', '2', '2.5', '1.75', 'NL', 'NL', 'NP']
# ['10. Detailed plain masonry shear walls', '14.4', '2', '2.5', '1.75', 'NL', 'NP', 'NP']
# ...
